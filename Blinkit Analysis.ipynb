# %% [markdown]
# ## ***DATA ANALYSIS PYTHON PROJECT - BLINKIT ANALYSIS***

# %% [markdown]
# #### ***1.Import Libraries***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# #### ***2.Reading Dataset***

# %%
df=pd.read_csv(r"C:\Users\ASUS\Desktop\Python Data Analyst Projects\Blinkit analysis\blinkit_data.csv")

# %%
#first 5 row
df.head()
# Out:
#   Item Fat Content Item Identifier              Item Type  \
# 0          Regular           FDX32  Fruits and Vegetables
# 1          Low Fat           NCB42     Health and Hygiene
# 2          Regular           FDR28           Frozen Foods
# 3          Regular           FDL50                 Canned
# 4          Low Fat           DRI25            Soft Drinks
#
#    Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                       2012            OUT049               Tier 1
# 1                       2022            OUT018               Tier 3
# 2                       2010            OUT046               Tier 1
# 3                       2000            OUT013               Tier 3
# 4                       2015            OUT045               Tier 2
#
#   Outlet Size        Outlet Type  Item Visibility  Item Weight     Sales  \
# 0      Medium  Supermarket Type1         0.100014        15.10  145.4786
# ...

# %%
#Szie of data
print("Size of Data:",df.shape)
# Out:
# Size of Data: (8523, 12)

# %% [markdown]
# #### ***3.Field Info***

# %%
df.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %% [markdown]
# #### ***4.Data Types***

# %%
df.dtypes
# Out:
# Item Fat Content              object
# Item Identifier               object
# Item Type                     object
# Outlet Establishment Year      int64
# Outlet Identifier             object
# Outlet Location Type          object
# Outlet Size                   object
# Outlet Type                   object
# Item Visibility              float64
# Item Weight                  float64
# Sales                        float64
# Rating                       float64
# dtype: object

# %%
print(df['Item Fat Content'].unique()) #checking unique values
# Out:
# ['Regular' 'Low Fat' 'low fat' 'LF' 'reg']

# %%
df['Item Fat Content']=df['Item Fat Content'].replace({'LF':'Low Fat','low fat':'Low Fat','reg':'Regular'})

# %% [markdown]
# ### ***BUSINESS REQUIREMENTS***

# %% [markdown]
# #### ***KPI's REQUIREMENTS***

# %%
#total sales
total_sales =df['Sales'].sum()

#Average Sales
avg_sales=df['Sales'].mean()

#No of Items Sold
no_of_items_sold=df['Sales'].count()

#Average Rating
avg_ratings=df['Rating'].mean()

#Display
print(f"Total Sales: ${total_sales:,.0f}")
print(f"Average Sales: ${avg_sales:,.0f}")
print(f"No of Items Sold: {no_of_items_sold:,.0f}")
print(f"Average Ratings: {avg_ratings:,.1f}")
# Out:
# Total Sales: $1,201,681
# Average Sales: $141
# No of Items Sold: 8,523
# Average Ratings: 4.0

# %% [markdown]
# ### ***CHARTS REQUIEMENTS***

# %% [markdown]
# #### ***1.Totals Sales by Fat Content***

# %%
sales_by_fat=df.groupby('Item Fat Content')['Sales'].sum()

figure=(figsize(4,4))
plt.pie(sales_by_fat, labels=sales_by_fat.index,autopct='%1.1f%%',startangle=90)
plt.title('sales by Fat Content')
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 sales_by_fat=df.groupby('Item Fat Content')['Sales'].sum()
# ----> 3 figure=(figsize(4,4))
#       4 plt.pie(sales_by_fat, labels=sales_by_fat.index,autopct='%1.1f%%',startangle=90)
#       5 plt.title('sales by Fat Content')
#
# NameError: name 'figsize' is not defined

# %% [markdown]
# #### ***2.Total Sales by Item Type***

# %%
# Grouping and sorting sales by item type
sales_by_type = df.groupby('Item Type')['Sales'].sum().sort_values(ascending=False)

# Plot settings
plt.figure(figsize=(12,6))
bars = plt.bar(sales_by_type.index, sales_by_type.values)

# Axis labels and title
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.xlabel('Item Type', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.title('Total Sales by Item Type', fontsize=14)

# Add value labels on top of bars
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2,
             bar.get_height(),
             f'{bar.get_height():,.0f}',
             ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### ***3.Fat Content by Outlet for Total Sales***

# %%
grouped = df.groupby(['Outlet Location Type', 'Item Fat Content'])['Sales'].sum().unstack()

# Optional: If you want to show only 'Regular' and 'Low Fat' columns in the plot
grouped = grouped[['Regular', 'Low Fat']]

ax = grouped.plot(kind='bar', figsize=(8, 5), title='Outlet Tier by Item Fat Content')
plt.xlabel('Outlet Location Tier', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.legend(title='Item Fat Content')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### ***4.Total Sales by Outlet Establlishment***

# %%
#Grouping sales by 'Outlet Establishment Year'
sales_by_year = df.groupby('Outlet Establishment Year')['Sales'].sum().sort_index()

plt.figure(figsize=(9, 5))
plt.plot(sales_by_year.index, sales_by_year.values, marker='o', linestyle='-')

plt.xlabel('Outlet Establishment Year', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.title('Total Sales by Outlet Establishment Year', fontsize=14)

#Annotating the points on the line
for x, y in zip(sales_by_year.index, sales_by_year.values):
    plt.text(x, y, f'{y:,.0f}', ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### ***5.Sales by Outlet Size***

# %%
sales_by_size=df.groupby('Outlet Size')['Sales'].sum()

plt.figure(figsize=(4,4))
plt.pie(sales_by_size, labels=sales_by_size.index,autopct='%1.1f%%',startangle=90)
plt.title('Outlet Size')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### ***6.Sales by Outlet Location***

# %%
sales_by_location = df.groupby('Outlet Location Type')['Sales'].sum().reset_index()
sales_by_location = sales_by_location.sort_values('Sales', ascending=False)

plt.figure(figsize=(8, 4))
ax = sns.barplot(x='Sales', y='Outlet Location Type', data=sales_by_location)

plt.xlabel('Total Sales', fontsize=12)
plt.ylabel('Outlet Location Type', fontsize=12)
plt.title('Total Sales by Outlet Location Type', fontsize=14)

plt.tight_layout()
plt.show()
